# %% [markdown]
# В этом ноутбуке продемонстрирован пример инференса модели на примере валидационной выборки из 10 случайных запросов
#
# Валидационная выборка состоит из полей:
# 1. Product Name - название продукта
# 2. clean_desc - описание товара от 10 слов
# 3. search_text - дефолтный текст запроса типа "soda" и тд. Сделано для всех 4к строк
# 4. abstract_search_text - абстрактный запрос вроде "Rich baking ingredients for traditional recipes", сделано для 20% датафрейма, остальное Nan
#
# У каждого товара есть 1 или 2 запроса. Для валидации мы к каждому запросу из тест сета моделью подберём 20 релевантных товаров с помощью модели

# %% [markdown]
# #### **инсталлы**

# %%
import torch
import transformers
import pandas as pd
import numpy as np
from tqdm import tqdm
from scipy.spatial.distance import cdist
from transformers import AutoTokenizer, DistilBertModel

# %%
def seed_everything(seed = 42, torch_deterministic = True):
  # TRY NOT TO MODIFY: seeding
  # random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  torch.backends.cudnn.deterministic = torch_deterministic

seed_everything(42)

# %% [markdown]
# #### **загрузка и подготовка данных**

# %%
df_val = pd.read_csv("/content/items_with_search_text.csv")
df_val = df_val[["Uniq Id", "Product Name", "clean_desc", "search_text", "abstract_search_text"]]
df_val.head()
# Out:
#                             Uniq Id  \
# 0  019b67ef7f01103d8fb0a53e4c36daa7
# 1  e4fab4b6f41eac02d22b421818c8f080
# 2  992c11a1b238eae6a2fabf22c74de5c2
# 3  290970606fd82ac39534aa32b8b3b149
# 4  21fee4394b9cc53bb6ddbe4235506a5c
#
#                                         Product Name  \
# 0     La Costena Chipotle Peppers, 7 OZ (Pack of 12)
# 1  (6 Boxes) Twinings of London Nightly Calm Gree...
# 2  Tiny White Mighty Mints (16 oz, ZIN: 525424) -...
# 3  SweetGourmet Narrow Sesame Sticks | Lightly Sa...
# 4  Health Warrior Chia Bar, Acai Berry, 25 G, Pac...
#
#                                           clean_desc       search_text  \
# 0  la costena chipotle peppers, 7 oz (pack of 12)...  chipotle peppers
# 1  enojy one of your favorite tea flavors with th...         green tea
# 2  tiny white mighty mints (16 oz, zin: 525424): ...             mints
# 3  narrow sesame sticks are fresh, crunchy and li...     sesame sticks
# 4  health warrior chia bar, acai berry is packed ...          chia bar
#
#            abstract_search_text
# 0      Mexican spice essentials
# 1         Soothing bedtime teas
# 2  Breath freshening essentials
# 3            Savory snack ideas
# 4    Healthy snack alternatives

# %% [markdown]
# #### **подготовка модели**

# %%
# модель для проверки
class Model:
    def __init__(self, product_DB: pd.DataFrame, to_set_up: bool = False, path_to_vector_BD: str = None):
        self.model = None
        self.tokenizer = None

        self.vector_DB = None
        if path_to_vector_BD:
            print("Downloading Vector BD")
            self.vector_DB = np.load(path_to_vector_BD)

        self.products_DB = product_DB.sort_values(by = "Uniq Id")


        if to_set_up:
            self.set_up()

    def set_up(self, max_position_embeddings = 512):
        self.tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
        self.model = DistilBertModel.from_pretrained("distilbert-base-uncased", max_position_embeddings = max_position_embeddings)

    def calc_embeding(self, X: str):
        if not self.model:
            print("U should set_up() nodel first!")
            return
        inputs = self.tokenizer(X[:512], return_tensors="pt")
        return self.model(**inputs).last_hidden_state[:,-1,:].detach().numpy()


    def form_vector_DB(self):
        if self.vector_DB is not None:
            print("Vector DB already exists!")
            return

        self.vector_DB = np.stack(
            tuple( self.calc_embeding(row["Description"]) for _, row in tqdm(self.products_DB.sort_values(by = "Uniq Id").iterrows(), total = len(self.products_DB))
            )
        )

    def get_n_rank(self, query, n = 10):
        if self.vector_DB is None:
            print("No Vector DB exists!")
            return

        if not self.model:
            print("U should set_up() nodel first!")
            return

        query_v = self.calc_embeding(query)
        top_indx = cdist(query_v, self.vector_DB, 'cosine')[0].argsort()[:n] # top most simular (with smallar distance)
        out_uniq_id = self.products_DB.sort_values(by = "Uniq Id").iloc[top_indx]["Uniq Id"]
        return out_uniq_id

# %%
# инициализируем модель для инференса
inference_model = Model(df_val, path_to_vector_BD = "vector_BD.npy", to_set_up = True)
# Out:
# Downloading Vector BD
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %% [markdown]
# #### **инференс на тестовых запросах**

# %%
# выберем k тестовых стандартных(не абстрактных) запросов случайно из выборки
seed_everything(42)
k = 10
random_indices = np.random.randint(0, len(df_val), size=k)

test_queries = df_val.loc[random_indices]
#test_products = df_val.loc[random_indices][["Uniq Id", "Product Name", "clean_desc"]]
test_queries
# Out:
#                                Uniq Id  \
# 3174  49211ae8276d458310dd06f536653fb8
# 3507  48f177144587bb50f2298a14fdc02b86
# 860   e84cb9e22be2bdf90e1e01b0a273c263
# 1294  325db3ffed5c3f15b53530920433bfa0
# 1130  cf37eea3b3566ea9e32b3f305875cbb3
# 1095  5a76983a268315991ec00c07c8033d85
# 3772  54386abe067dc221416bfb2e99b791b9
# 3092  9a359f5429f285a357ce897f04581950
# 1638  236841b9b5a1638b3efdec7773142252
# 2169  094bb5316592e045a38c0bb51addc056
#
#                                            Product Name  \
# 3174  Yumbutter Superfood Almond Butter - Case Of 6 ...
# 3507                    Setton Farms Omega-3 Mix, 18 Oz
# 860   Sanpellegrino Orange Sparkling Fruit Beverage,...
# 1294  Lily Of The Desert Organic Aloe Vera Juice Who...
# 1130  Raymundos No Added Sugar Strawberry Fruit & Ge...
# 1095  Bulletproof Glutathione Force, Master Antioxid...
# 3772  LaCroix Sparkling Water - PinaFraise "Strawber...
# 3092      Cafe Bustelo Espresso Ground Coffee, 10 Ounce
# 1638   Peytons Thick Sliced Double Smoked Bacon, 12 Oz.
# 2169  Vibrant health green vibrance superfood powder...
#
#                                              clean_desc           search_text  \
# 3174  yumbutter superfood almond butter - case of 6 ...         Almond butter
# 3507  setton farms mixes are created with unique ble...           omega-3 mix
# 860   inspired by homemade italian aranciata, sanpel...    Sparkling beverage
# 1294  lily of the desert organic aloe vera juice who...       Aloe vera juice
# 1130  fruit & gel 7.5oz raymundos straw frt & gel 7.5oz      Strawberry snack
# 1095  strengthen your body against the toxins and st...  antioxidant capsules
# 3772  lacroix sparkling water is the #1 sparkling wa...       Sparkling water
# 3092  cafe bustelo for flavor, aroma and quality is ...       Espresso coffee
# 1638  u.s. inspected and passed by department of agr...          Smoked bacon
# 2169  our vitality is the sum total of the health of...      superfood powder
#
#      abstract_search_text
# 3174                  NaN
# 3507                  NaN
# 860                   NaN
# 1294                  NaN
# 1130                  NaN
# 1095                  NaN
# 3772                  NaN
# 3092                  NaN
# 1638                  NaN
# 2169                  NaN

# %%
# проинферим модель на запросах
top_n = 20
model_output = dict()
for row in test_queries.iterrows():
  product_ids = inference_model.get_n_rank(row[1]["search_text"], top_n)
  model_output[row[1]["Uniq Id"]] = product_ids

# %%
# проитерируемся по выходам модели и посмотрим на запросы и то, что модель выдала на них
for uniq_id in model_output.keys():
  row = test_queries[test_queries["Uniq Id"] == uniq_id]
  predicted_product_ids = model_output[uniq_id]

  print(f"query was: {row['search_text'].item()} \ncorrect product is: {row['Product Name'].item()}")
  print(f"predicted products are:\n {df_val[df_val['Uniq Id'].isin(predicted_product_ids)]['Product Name'].values}\n\n")
# Out:
# query was: Almond butter
# correct product is: Yumbutter Superfood Almond Butter - Case Of 6 - 6.2 Oz
# predicted products are:
#  ['Corn Starch (8 oz, ZIN: 526021) - 3-Pack'
#  '4 Pack - Humco Cola Syrup 4 oz Each'
#  'Two Leaves and a Bud, Inc., Organic Earl Grey Black Tea, 15 Count'
#  'Vienna Beef - Smoked Beef Stix (2.5Lbs)'
#  '(2 Pack) Great Value 4 in 1 Decorating Sprinkles, All Occasion, 5.2 oz'
#  'Folgers Brazilian Blend Ground Coffee, Medium Roast, 24.2 Ounce'
#  'Judees Gluten Free Guar Gum Powder, 10 oz'
#  'Kind Plus Bars, 1.4 oz bars, Cranberry Almond + Antioxidants 12 bars'
#  '(3 Boxes) Bigelow, Red Raspberry, Tea Bags, 20 Ct'
#  'Pacific Natural Foods Coconut Original - Non Dairy - Case of 12 - 32 Fl oz.'
#  'Boost Kid Oral Supplement Esentials Vanilla 8.25 oz. Ready to Use CS|16 PK|2'
#  'Ganoderma Coffe Reyshen Red 200gms. Cafe Organico con Hongo Ganoderma Rojo 200grms'
#  '(2 Pack) Smuckers Natural Concord Grape Fruit Spread, 12.75 oz'
#  'Adolphs Meat Loaf Mix, 2.11 oz (Pack of 6)'
#  'Cafe Rey Selecto Costa Rica Ground Premium Coffee - 8.8 Oz (250 gr)'
#  '(12 Pack) Pacific Natural Foods Almond Vanilla - Unsweetened, 32 oz'
#  'Cajun Chef Products Cajun Chef Louisiana Sport Peppers, 6 oz'
#  'Farmers Market Cage Free Large Grande A Eggs, 12 Count'
#  'Wilmington Prints Essentials Soda Pop Pineapple Soda Pop'
#  'Great Value Sliced Olives, 7.05 oz']
#
#
# query was: omega-3 mix
# correct product is: Setton Farms Omega-3 Mix, 18 Oz
# predicted products are:
#  ['Corn Starch (8 oz, ZIN: 526021) - 3-Pack'
#  '4 Pack - Humco Cola Syrup 4 oz Each'
#  'Two Leaves and a Bud, Inc., Organic Earl Grey Black Tea, 15 Count'
#  'Lee Kum Kee Black bean garlic sauce - 8 oz'
#  'Giuliano Pepper Sport Chicago Style, 16 OZ (Pack of 6)'
#  'Judees Gluten Free Guar Gum Powder, 10 oz'

#  'Adolphs Meat Loaf Mix, 2.11 oz (Pack of 6)'
#  'Cafe Rey Selecto Costa Rica Ground Premium Coffee - 8.8 Oz (250 gr)'
#  '(12 Pack) Pacific Natural Foods Almond Vanilla - Unsweetened, 32 oz'
#  'Gino---Blue Mountain Flavor Coffee Hazelnut Flavor Coffee Powder. Premix Instant Coffee ( 3 in 1 ) Offer a Relaxing Flavor Strong Solid Essence and Aroma. (1 Pack Blue Mountain 1 pack Hazelnut)'
#  'Extra Polar Ice'
#  'Farmers Market Cage Free Large Grande A Eggs, 12 Count'
#  'Pomi Tomato Sauce, 17.64 oz, (Pack of 12)'
#  'Wilmington Prints Essentials Soda Pop Pineapple Soda Pop'
#  'Great Value Sliced Olives, 7.05 oz']
#
#
# query was: Espresso coffee
# correct product is: Cafe Bustelo Espresso Ground Coffee, 10 Ounce
# predicted products are:
#  ['Vienna Beef - Smoked Beef Stix (2.5Lbs)'
#  'Folgers Brazilian Blend Ground Coffee, Medium Roast, 24.2 Ounce'
#  'Judees Gluten Free Guar Gum Powder, 10 oz'
#  'Kind Plus Bars, 1.4 oz bars, Cranberry Almond + Antioxidants 12 bars'
#  'Natures Charm Sweetened Condensed Coconut Milk 7.05oz Pack of 12'
#  'Pacific Natural Foods Coconut Original - Non Dairy - Case of 12 - 32 Fl oz.'
#  'Boost Kid Oral Supplement Esentials Vanilla 8.25 oz. Ready to Use CS|16 PK|2'
#  'Dell Alpe Peperoncini, 24 OZ (Pack of 12)'
#  'Sweet Tarts Conversation Hearts 5 pounds Sweet Tart Candy'
#  'Starbucks Frappuccino Light Mocha Coffee Drink, 13.7 fl oz'
#  'Great Value Gelatin Dessert, Orange, 3 oz'
#  'Ganoderma Coffe Reyshen Red 200gms. Cafe Organico con Hongo Ganoderma Rojo 200grms'
#  'Nabisco Minis Premium Original Saltine Crackers, 11 Oz.'
#  '(12 Pack) Pacific Natural Foods Almond Vanilla - Unsweetened, 32 oz'
#  'Navitas Naturals Protein Powder, Hemp, 12 Oz'
#  'Christopher Bean Coffee Decaf Gingerbread Creme Brulee K-Cup Coffee Pods, 18 Count For Keurig Brewers'
#  'Walden Farms Calorie Free Syrups - Available in 7 Flavors! Flavors: Maple Walnut Syrup, Size: 6-Pack'
#  'Farmers Market Cage Free Large Grande A Eggs, 12 Count'
#  'Lee Kum Kee PREMIUM SOY SAUCE FAMILY PACK 59 fl oz each Bottle (1 PACK)'
#  'Natures Path Organic Qia Superfood Cereal, Cranberry Vanilla, 7.9 Oz']
#
#
# query was: Smoked bacon
# correct product is: Peytons Thick Sliced Double Smoked Bacon, 12 Oz.
# predicted products are:
#  ['Corn Starch (8 oz, ZIN: 526021) - 3-Pack'
#  'Two Leaves and a Bud, Inc., Organic Earl Grey Black Tea, 15 Count'
#  'Folgers Brazilian Blend Ground Coffee, Medium Roast, 24.2 Ounce'
#  'Food To Live Â Organic Walnuts (Raw, No Shell) (2.5 Pounds)'
#  'Kind Plus Bars, 1.4 oz bars, Cranberry Almond + Antioxidants 12 bars'
#  '(3 Boxes) Bigelow, Red Raspberry, Tea Bags, 20 Ct'
#  'Pacific Natural Foods Coconut Original - Non Dairy - Case of 12 - 32 Fl oz.'
#  'Boost Kid Oral Supplement Esentials Vanilla 8.25 oz. Ready to Use CS|16 PK|2'
#  'Dell Alpe Peperoncini, 24 OZ (Pack of 12)'
#  '(6 Pack) Del Monte No Sugar Added Fruit Cocktail, 14.5 oz'
#  'Just Date Syrup 7.05 oz each (6 Items Per Order, not per case)'
#  'Starbucks Frappuccino Light Mocha Coffee Drink, 13.7 fl oz'
#  'Ganoderma Coffe Reyshen Red 200gms. Cafe Organico con Hongo Ganoderma Rojo 200grms'
#  'Adolphs Meat Loaf Mix, 2.11 oz (Pack of 6)'
#  '(12 Pack) Pacific Natural Foods Almond Vanilla - Unsweetened, 32 oz'
#  'Supreme by Bustelo Freeze Dried Instant Coffee'
#  'Yumearth Organics - Organic Fruit Snack - 4 Flavors - Case Of 12 - 2 Oz.'
#  'Farmers Market Cage Free Large Grande A Eggs, 12 Count'
#  'Wilmington Prints Essentials Soda Pop Pineapple Soda Pop'
#  'Great Value Sliced Olives, 7.05 oz']
#
#
# query was: superfood powder
# correct product is: Vibrant health green vibrance superfood powder, 2.2 lb
# predicted products are:
#  ['(2 Pack) Krusteaz Honey Wheat Pancake Mix, 25.2oz Box'
#  'Acetaia Reale Saba Vinegar - 8.5 fl oz (250mL) Italian Grape Must Vinegar'
#  'Vienna Beef - Smoked Beef Stix (2.5Lbs)'
#  'Airwaves Gum Menthol. 20 Packs'
#  'BAYSIDE CANDY ENGLISH LICORICE ALLSORTS, 1LB'
#  'Folgers Brazilian Blend Ground Coffee, Medium Roast, 24.2 Ounce'
#  'Judees Gluten Free Guar Gum Powder, 10 oz'
#  'Gatorade G2 Lower Sugar Thirst Quencher, Grape, 12 Ounce Bottles (Pack of 12)'
#  'Kind Plus Bars, 1.4 oz bars, Cranberry Almond + Antioxidants 12 bars'
#  'Great Value Gelatin Dessert, Orange, 3 oz'
#  'Ganoderma Coffe Reyshen Red 200gms. Cafe Organico con Hongo Ganoderma Rojo 200grms'
#  'Great Value Organic Blue Corn Tortilla Chip Bowls, 8 oz'
#  '(2 Pack) Smuckers Natural Concord Grape Fruit Spread, 12.75 oz'
#  'Adolphs Meat Loaf Mix, 2.11 oz (Pack of 6)'
#  'Gino---Blue Mountain Flavor Coffee Hazelnut Flavor Coffee Powder. Premix Instant Coffee ( 3 in 1 ) Offer a Relaxing Flavor Strong Solid Essence and Aroma. (1 Pack Blue Mountain 1 pack Hazelnut)'
#  'Tony Packos Original Pickles & Peppers, 24 fl oz, (Pack of 6)'
#  'Thai Kitchen Gluten Free Red Curry Paste, 4 oz'
#  'Aspen Mulling Hot Chocolate, Salted Caramel, 4-pack'
#  'Great Value Oregano Leaves, 5.5 oz'
#  'Wilmington Prints Essentials Soda Pop Pineapple Soda Pop']

# %% [markdown]
# #### **вывод по инференсу**
#
# На 10 тестовых запросах по топ 20 продуктов на каждый видим, что необученный берт пока не может подтянуть товар, по которому создавался запрос, однако в выдаче есть релевантные товары, например, для запроса Espresso coffee в выдаче есть другие виды кофе, а на запрос Strawberry snack выдаются десерты/чай
#
# Для дальнейшей работы по улучшению качества модели можно выделить следующие варианты:
#
# 1. взять модель побольше и возможно предобученную на доменах ретейл/ecom
# 2. попробовать другой датасет
# 3. добавить препроцессинг описания товаров/запросов
